# %% [markdown]
# ### Load Necessary Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Line Graph

# %%
gas = pd.read_csv('https://raw.githubusercontent.com/subhajit008/data-jpn/refs/heads/main/a.csv')
gas.head(10)
# Out:
#    GateV  DrainV  VssV BodyV  VddV        DrainI         GateI          VssI  \
# 0   0.00     0.0     0  -0.4   0.8  2.800000e-12 -3.760000e-12 -1.950000e-12
# 1   0.02     0.0     0  -0.4   0.8  2.900000e-13 -1.294000e-11 -4.830000e-12
# 2   0.04     0.0     0  -0.4   0.8  2.600000e-12 -4.870000e-12 -1.123000e-11
# 3   0.06     0.0     0  -0.4   0.8  7.200000e-13 -2.600000e-13 -6.910000e-12
# 4   0.08     0.0     0  -0.4   0.8  2.680000e-12  6.240000e-12 -4.640000e-12
# 5   0.10     0.0     0  -0.4   0.8 -5.500000e-13  1.313000e-11 -5.300000e-13
# 6   0.12     0.0     0  -0.4   0.8  2.790000e-12  8.670000e-12  7.530000e-12
# 7   0.14     0.0     0  -0.4   0.8  6.500000e-13  1.106000e-11  4.140000e-12
# 8   0.16     0.0     0  -0.4   0.8  1.620000e-12  2.590000e-12  7.200000e-13
# 9   0.18     0.0     0  -0.4   0.8  2.050000e-12  6.420000e-12  1.680000e-12
#
#           BodyI          VddI  TempK  GNDV
# 0 -2.510000e-12  2.700000e-13    8.5   0.0
# ...

# %%
# @title DrainV

from matplotlib import pyplot as plt
gas['DrainV'].plot(kind='line', figsize=(8, 4), title='DrainV')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['GateV']
  ys = series['VssI']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_10.sort_values('GateV', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('GateV')
_ = plt.ylabel('VssI')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['GateV']
  ys = series['GateI']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_9.sort_values('GateV', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('GateV')
_ = plt.ylabel('GateI')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['GateV']
  ys = series['DrainI']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_8.sort_values('GateV', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('GateV')
_ = plt.ylabel('DrainI')

# %%
gas = pd.read_csv('https://raw.githubusercontent.com/subhajit008/data-jpn/refs/heads/main/a.csv')

# plt.figure(figsize=(100,100))

# plt.title('Gas Prices over Time (in USD)', fontdict={'fontweight':'bold', 'fontsize': 18})

plt.plot( gas.TempK, gas.GateV,  label='TempK vs GateV')




plt.legend()

# plt.savefig('Gas_price_figure.png', dpi=300)

plt.show()

# %%
plt.plot(gas.BodyI, gas.VssI, label="BodyI vs VssI")

# %%
plt.plot(gas.GateI, gas.VssI, label="GateI vs VssI")
